# %%
import os
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.utils import np_utils
from sklearn.model_selection import KFold

# Define train and test paths
train_path = 'C:/Users/Nayan/Desktop/Project/DevanagariHandwrittenDigitDataset/Train'
test_path = 'C:/Users/Nayan/Desktop/Project/DevanagariHandwrittenDigitDataset/Test'

# Define the number of classes
num_classes = 10

# Define image size and number of channels
img_rows, img_cols, img_channels = 32, 32, 1

# Define a function to load the data from the specified path
import re

def load_data(path):
    data = []
    labels = []
    pattern = r"\d+" # regular expression to match digits in folder name
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        for file in os.listdir(folder_path):
            file_path = os.path.join(folder_path, file)
            image = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            image = cv2.resize(image, (img_rows, img_cols))
            data.append(image)
            match = re.search(pattern, folder)
            labels.append(int(match.group())) # convert matched digits to integer label
    data = np.array(data)
    data = data.reshape(data.shape[0], img_rows, img_cols, img_channels)
    data = data.astype('float32')
    data /= 255
    labels = np.array(labels)
    labels = np_utils.to_categorical(labels, num_classes)
    return data, labels

# Load the data
X, y = load_data(train_path)

# Define the CNN-LSTM model
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same', activation='relu', input_shape=(img_rows, img_cols, img_channels)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
from keras.layers import Reshape
from keras.layers import TimeDistributed, LSTM, Dense
model.add(Flatten())
model.add(Reshape((8, 8, 64)))
model.add(TimeDistributed(Flatten()))
model.add(TimeDistributed(Dense(128)))
model.add(LSTM(128, return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

# %%
# Compile the model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Define the number of folds
K = 3

# Define the KFold object
kf = KFold(n_splits=K, shuffle=True)

# Define lists to store the accuracy and loss for each fold
acc_per_fold = []
loss_per_fold = []

# %%
# Loop over the folds
fold_no = 1
for train_idx, val_idx in kf.split(X):
    # Split the data into training and validation sets for this fold
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    
    # Train the model on the training data for this fold
    model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=20, batch_size=64)
    
    # Evaluate the model on the validation data for this fold
    scores = model.evaluate(X_val, y_val, verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    acc_per_fold.append(scores[1] * 100)
    loss_per_fold.append(scores[0])
    
    # Increment the fold number
    fold_no += 1
# Out:
# Epoch 1/20
# 178/178 [==============================] - 19s 82ms/step - loss: 0.0030 - accuracy: 0.9991 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 2/20
# 178/178 [==============================] - 15s 83ms/step - loss: 0.0028 - accuracy: 0.9989 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 3/20
# 178/178 [==============================] - 14s 76ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0027 - val_accuracy: 0.9991
# Epoch 4/20
# 178/178 [==============================] - 12s 69ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0012 - val_accuracy: 0.9994
# Epoch 5/20
# 178/178 [==============================] - 12s 67ms/step - loss: 6.4609e-04 - accuracy: 0.9998 - val_loss: 5.4919e-05 - val_accuracy: 1.0000
# Epoch 6/20
# 178/178 [==============================] - 12s 68ms/step - loss: 0.0028 - accuracy: 0.9992 - val_loss: 0.0130 - val_accuracy: 0.9962
# Epoch 7/20
# 178/178 [==============================] - 13s 71ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 0.0016 - val_accuracy: 0.9988
# Epoch 8/20
# 178/178 [==============================] - 12s 67ms/step - loss: 0.0024 - accuracy: 0.9996 - val_loss: 9.0973e-04 - val_accuracy: 0.9997
# Epoch 9/20
# 178/178 [==============================] - 13s 71ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0053 - val_accuracy: 0.9991
# Epoch 10/20
# 178/178 [==============================] - 13s 74ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0022 - val_accuracy: 0.9994
# Epoch 11/20
# 178/178 [==============================] - 13s 74ms/step - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0026 - val_accuracy: 0.9991
# Epoch 12/20
# 178/178 [==============================] - 14s 80ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 2.1466e-04 - val_accuracy: 1.0000
# Epoch 13/20
# 178/178 [==============================] - 12s 69ms/step - loss: 1.4766e-04 - accuracy: 1.0000 - val_loss: 1.0543e-04 - val_accuracy: 1.0000
# Epoch 14/20
# 178/178 [==============================] - 12s 68ms/step - loss: 7.0786e-05 - accuracy: 1.0000 - val_loss: 7.0358e-05 - val_accuracy: 1.0000
# Epoch 15/20
# 178/178 [==============================] - 12s 70ms/step - loss: 5.6857e-05 - accuracy: 1.0000 - val_loss: 5.1643e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 178/178 [==============================] - 12s 69ms/step - loss: 4.3825e-05 - accuracy: 1.0000 - val_loss: 4.2544e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 178/178 [==============================] - 14s 76ms/step - loss: 5.5247e-05 - accuracy: 1.0000 - val_loss: 3.4445e-05 - val_accuracy: 1.0000
# Epoch 18/20
# 178/178 [==============================] - 13s 75ms/step - loss: 3.6888e-05 - accuracy: 1.0000 - val_loss: 2.8972e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 178/178 [==============================] - 14s 79ms/step - loss: 3.4045e-05 - accuracy: 1.0000 - val_loss: 2.7633e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 178/178 [==============================] - 13s 71ms/step - loss: 2.3781e-05 - accuracy: 1.0000 - val_loss: 2.5758e-05 - val_accuracy: 1.0000
# Score for fold 1: loss of 0.0020910457242280245; accuracy of 99.982351064682%
# Epoch 1/20
# 178/178 [==============================] - 14s 81ms/step - loss: 0.0033 - accuracy: 0.9991 - val_loss: 0.0324 - val_accuracy: 0.9914
# Epoch 2/20
# 178/178 [==============================] - 14s 77ms/step - loss: 0.0114 - accuracy: 0.9966 - val_loss: 0.0145 - val_accuracy: 0.9951
# Epoch 3/20
# 178/178 [==============================] - 13s 75ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0080 - val_accuracy: 0.9981
# Epoch 4/20
# 178/178 [==============================] - 14s 76ms/step - loss: 0.0043 - accuracy: 0.9989 - val_loss: 0.0081 - val_accuracy: 0.9975
# Epoch 5/20
# 178/178 [==============================] - 14s 77ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0010 - val_accuracy: 0.9998
# Epoch 6/20
# 178/178 [==============================] - 13s 76ms/step - loss: 3.4279e-04 - accuracy: 1.0000 - val_loss: 0.0020 - val_accuracy: 0.9991
# Epoch 7/20
# 178/178 [==============================] - 13s 74ms/step - loss: 3.7318e-04 - accuracy: 0.9999 - val_loss: 0.0013 - val_accuracy: 0.9995
# Epoch 8/20
# 178/178 [==============================] - 14s 80ms/step - loss: 2.1657e-04 - accuracy: 1.0000 - val_loss: 0.0014 - val_accuracy: 0.9995
# Epoch 9/20
# 178/178 [==============================] - 14s 78ms/step - loss: 1.6922e-04 - accuracy: 1.0000 - val_loss: 0.0021 - val_accuracy: 0.9995
# Epoch 10/20
# 178/178 [==============================] - 14s 79ms/step - loss: 5.3418e-05 - accuracy: 1.0000 - val_loss: 9.5278e-04 - val_accuracy: 0.9996
# Epoch 11/20
# 178/178 [==============================] - 14s 78ms/step - loss: 3.2867e-05 - accuracy: 1.0000 - val_loss: 9.2164e-04 - val_accuracy: 0.9998
# Epoch 12/20
# 178/178 [==============================] - 15s 82ms/step - loss: 2.9107e-05 - accuracy: 1.0000 - val_loss: 8.9480e-04 - val_accuracy: 0.9998
# Epoch 13/20
# 178/178 [==============================] - 13s 75ms/step - loss: 3.5014e-05 - accuracy: 1.0000 - val_loss: 8.3323e-04 - val_accuracy: 0.9998
# Epoch 14/20
# 178/178 [==============================] - 14s 81ms/step - loss: 2.4593e-05 - accuracy: 1.0000 - val_loss: 7.9474e-04 - val_accuracy: 0.9998
# Epoch 15/20
# 178/178 [==============================] - 14s 78ms/step - loss: 2.0444e-05 - accuracy: 1.0000 - val_loss: 7.3068e-04 - val_accuracy: 0.9998
# Epoch 16/20
# 178/178 [==============================] - 14s 81ms/step - loss: 2.0845e-05 - accuracy: 1.0000 - val_loss: 6.1547e-04 - val_accuracy: 0.9998
# Epoch 17/20
# 178/178 [==============================] - 14s 81ms/step - loss: 1.6997e-05 - accuracy: 1.0000 - val_loss: 5.9007e-04 - val_accuracy: 0.9998
# Epoch 18/20
# 178/178 [==============================] - 13s 75ms/step - loss: 1.3090e-05 - accuracy: 1.0000 - val_loss: 6.1514e-04 - val_accuracy: 0.9998
# Epoch 19/20
# 178/178 [==============================] - 15s 85ms/step - loss: 1.2090e-05 - accuracy: 1.0000 - val_loss: 6.5029e-04 - val_accuracy: 0.9998
# Epoch 20/20
# 178/178 [==============================] - 14s 78ms/step - loss: 1.0591e-05 - accuracy: 1.0000 - val_loss: 6.2326e-04 - val_accuracy: 0.9998
# Score for fold 2: loss of 0.000623264058958739; accuracy of 99.982351064682%
# Epoch 1/20
# 178/178 [==============================] - 14s 79ms/step - loss: 0.0241 - accuracy: 0.9923 - val_loss: 0.0187 - val_accuracy: 0.9942
# Epoch 2/20
# 178/178 [==============================] - 15s 82ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.0019 - val_accuracy: 0.9996
# Epoch 3/20
# 178/178 [==============================] - 14s 76ms/step - loss: 8.0404e-04 - accuracy: 0.9999 - val_loss: 5.9620e-04 - val_accuracy: 0.9998
# Epoch 4/20
# 178/178 [==============================] - 15s 82ms/step - loss: 2.8820e-04 - accuracy: 0.9999 - val_loss: 3.7487e-04 - val_accuracy: 0.9998
# Epoch 5/20
# 178/178 [==============================] - 14s 78ms/step - loss: 2.2990e-04 - accuracy: 1.0000 - val_loss: 1.7167e-04 - val_accuracy: 1.0000
# Epoch 6/20
# 178/178 [==============================] - 14s 79ms/step - loss: 1.1278e-04 - accuracy: 1.0000 - val_loss: 1.1312e-04 - val_accuracy: 1.0000
# Epoch 7/20
# 178/178 [==============================] - 13s 76ms/step - loss: 6.1478e-05 - accuracy: 1.0000 - val_loss: 8.0674e-05 - val_accuracy: 1.0000
# Epoch 8/20
# 178/178 [==============================] - 14s 76ms/step - loss: 5.9968e-05 - accuracy: 1.0000 - val_loss: 6.9498e-05 - val_accuracy: 1.0000
# Epoch 9/20
# 178/178 [==============================] - 14s 76ms/step - loss: 4.7567e-05 - accuracy: 1.0000 - val_loss: 6.5060e-05 - val_accuracy: 1.0000
# Epoch 10/20
# 178/178 [==============================] - 14s 80ms/step - loss: 4.0714e-05 - accuracy: 1.0000 - val_loss: 5.7696e-05 - val_accuracy: 1.0000
# Epoch 11/20
# 178/178 [==============================] - 14s 76ms/step - loss: 3.7094e-05 - accuracy: 1.0000 - val_loss: 5.0171e-05 - val_accuracy: 1.0000
# Epoch 12/20
# 178/178 [==============================] - 13s 75ms/step - loss: 3.4374e-05 - accuracy: 1.0000 - val_loss: 4.0853e-05 - val_accuracy: 1.0000
# Epoch 13/20
# 178/178 [==============================] - 13s 75ms/step - loss: 2.7997e-05 - accuracy: 1.0000 - val_loss: 3.5947e-05 - val_accuracy: 1.0000
# Epoch 14/20
# 178/178 [==============================] - 14s 77ms/step - loss: 2.3964e-05 - accuracy: 1.0000 - val_loss: 3.2494e-05 - val_accuracy: 1.0000
# Epoch 15/20
# 178/178 [==============================] - 14s 77ms/step - loss: 1.8884e-05 - accuracy: 1.0000 - val_loss: 2.9727e-05 - val_accuracy: 1.0000
# Epoch 16/20
# 178/178 [==============================] - 15s 84ms/step - loss: 1.9231e-05 - accuracy: 1.0000 - val_loss: 3.0477e-05 - val_accuracy: 1.0000
# Epoch 17/20
# 178/178 [==============================] - 14s 77ms/step - loss: 1.6507e-05 - accuracy: 1.0000 - val_loss: 2.8924e-05 - val_accuracy: 1.0000
# Epoch 18/20
# 178/178 [==============================] - 14s 78ms/step - loss: 2.0018e-05 - accuracy: 1.0000 - val_loss: 3.1794e-05 - val_accuracy: 1.0000
# Epoch 19/20
# 178/178 [==============================] - 14s 77ms/step - loss: 1.4068e-05 - accuracy: 1.0000 - val_loss: 3.4257e-05 - val_accuracy: 1.0000
# Epoch 20/20
# 178/178 [==============================] - 13s 73ms/step - loss: 1.5735e-05 - accuracy: 1.0000 - val_loss: 2.3900e-05 - val_accuracy: 1.0000
# Score for fold 3: loss of 2.3900165615486912e-05; accuracy of 100.0%

# %%
# Print the overall accuracy and loss across all folds
print('------------------------------------------------------------------------')
print('Score per fold:')
for i in range(K):
    print(f'Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+/- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
model.save("conv_model_Final.hdf5")
# Out:
# ------------------------------------------------------------------------
# Score per fold:
# Fold 1 - Loss: 0.0020910457242280245 - Accuracy: 99.982351064682%
# Fold 2 - Loss: 0.000623264058958739 - Accuracy: 99.982351064682%
# Fold 3 - Loss: 2.3900165615486912e-05 - Accuracy: 100.0%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 99.98823404312134 (+/- 0.008319787896050482)
# > Loss: 0.0009127366496007502
